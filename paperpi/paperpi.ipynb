# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import logging.config
import sys
import shutil
from itertools import cycle
from inspect import getfullargspec
from importlib import import_module
from pathlib import Path
from distutils.util import strtobool
from time import sleep
from configparser import DuplicateSectionError
from configparser import Error as ConfigParserError

# %%
import ArgConfigParse
from epdlib import Screen
from epdlib.Screen import Update
from epdlib.Screen import ScreenError

# %%
from library.Plugin import Plugin
from library.CacheFiles import CacheFiles
from library.InterruptHandler import InterruptHandler
from library import get_help
from library import run_module
import my_constants as constants

# %%
# load the logging configuration
logging.config.fileConfig(constants.LOGGING_CONFIG)
logger = logging.getLogger(__name__)

# %%
def do_exit(status=0, message=None, **kwargs):
    '''exit with optional message
    Args:
        status(int): integers > 0 exit with optional message
        message(str): optional message to print'''
    if message:
        if status > 0:
            logger.error(f'failure caused exit: {message}')
        border = '\n'+'#'*70 + '\n'
        message = border + message + border + '\n***Exiting***'
        print(message)
        
    try:
        sys.exit(status)
    except Exception as e:
        pass

# %%
def config_str_to_val(config):
    '''convert strings in config dictionary into appropriate types
             float like strings ('7.1', '100.2', '-1.3') -> to float
             int like strings ('1', '100', -12) -> int
             boolean like strings (yes, no, Y, t, f, on, off) -> 0 or 1
             
         Args:
             config(`dict`): nested config.ini style dictionary

         Returns:
             `dict`'''    

    def eval_expression(string):
        '''safely evaluate strings allowing only specific names
        see: https://realpython.com/python-eval-function/
        
        e.g. "2**3" -> 8; "True" -> True; '-10.23' -> 10.23
        
        Args:
            string(str): string to attempt to evaluate
            
        Returns:
            evaluated as bool, int, real, etc.'''
        
        # set dict of allowed strings to and related names e.g. {"len": len}
        allowed_names = {}
        
        # compile the string into bytecode
        code = compile(string, "<string>", "eval")
        
        # check .co_names on the bytecode object to make sure it only contains allowed names
        for name in code.co_names:
            if name not in allowed_names:
                # raise a NameError for any name that's not allowed
                raise NameError(f'use of {name} not allowed')
        return eval(code, {"__builtins__": {}}, allowed_names)
    
    def convert(d, function, exceptions):
        '''convert value strings in dictionary to appropriate type using `function`
        
        d(dict): dictionary of dictionary of key/value pairs
        function(`func`): type to convert d into
        exceptions(tuple of Exceptions): tuple of exception types to ignore'''
        for section, values in d.items():
            for key, value in values.items():
                if isinstance(value, str):
                    try:
                        sanitized = function(value)
                    except exceptions:
                        sanitized = value

                    d[section][key] = sanitized
                else:
                    d[section][key] = value
        return d
    
    # evaluate int, float, basic math: 2+2, 2**15, 23.2 - 19
    convert(config, eval_expression, (NameError, SyntaxError))
    # convert remaining strings into booleans (if possible)
    # use the distuitls strtobool function
    convert(config, strtobool, (ValueError, AttributeError))
    
    # return converted values and original strings
    
    return config

# %%
def get_cmd_line_args():
    '''process command line arguments
    
    Returns:
        dict of parsed config values'''
    
    cmd_args = ArgConfigParse.CmdArgs()
    
    cmd_args.add_argument('--add_config', 
                         required=False, default=None, nargs=2,
                         metavar=('plugin', 'user|daemon'),
                         ignore_none = True,
                         help='copy sample config to the user or daemon configuration file')    
    
    cmd_args.add_argument('-c', '--config', ignore_none=True, metavar='CONFIG_FILE.ini',
                         type=str, dest='user_config',
                         help='use the specified configuration file')
    
    cmd_args.add_argument('-C', '--compatible', required=False,
                         default=False, action='store_true', 
                         help='list compatible displays and exit')
    
    cmd_args.add_argument('-l', '--log_level', ignore_none=True, metavar='LOG_LEVEL',
                         type=str, choices=['DEBUG', 'INFO', 'WARNING', 'ERROR'],
                         dest='main__log_level', help='change the log output level')
    
    cmd_args.add_argument('-d', '--daemon', required=False, default=False,
                         dest='main__daemon', action='store_true', 
                         help='run in daemon mode (ignore user configuration if found)')    
    
    cmd_args.add_argument('--list_plugins', required=False,
                         default=False, action='store_true', 
                         help='list all available plugins')

    cmd_args.add_argument('--plugin_info', metavar='[plugin|plugin.function]',
                         required=False, default=None,
                         ignore_none=True,
                         help='get information for plugins and user-facing functions provided by a plugin')   
    
    cmd_args.add_argument('--run_plugin_func',
                         required=False, default=None, nargs='+',
                         metavar=('plugin.function', 'optional_arg1 arg2 argN'),
                         ignore_none=True,
                         help='run a user-facing function for a plugin')
    
    cmd_args.add_argument('-V', '--version', required=False, default=False, ignore_false=True,
                          action='store_true',
                          help='display version and exit')
    
    cmd_args.parse_args()    

    return cmd_args

# %%
def get_config_files(cmd_args):
    '''read config.ini style files(s)
    
    Args: 
        cmd_args(`ArgConfigParse.CmdArgs` obj)
        
    Returns:
        ArgConfigParse.ConfgifFile'''
    
    config_files_dict = {'base': constants.CONFIG_BASE,
                         'system': constants.CONFIG_SYSTEM,
                         'user': constants.CONFIG_USER,
                         'cmd_line': cmd_args.options.user_config}
    
    config_files_list = [config_files_dict['base']]
    
    if config_files_dict['cmd_line']:
        config_file = config_files_dict['cmd_line']
    else:
        if cmd_args.options.main__daemon:
            config_file = config_files_dict['system']
        else:
            config_file = config_files_dict['user']
            if not config_file.exists():
                try:
                    constants.CONFIG_USER.parent.mkdir(parents=True, exist_ok=True)
                except PermissionError as e:
                    msg=f'could not create user configuration directory: {constants.CONFIG_USER.parent}'
                    logger.critical(msg)
                    do_exit(1, msg)
                try:
                    shutil.copy(constants.CONFIG_BASE, constants.CONFIG_USER)
                except Exception as e:
                    msg=f'could not copy user configuration file to {constants.CONFIG_USER}'
                    logging.critical(1, msg)
                    do_exit(1, msg)
                msg = f'''This appears to be the first time PaperPi has been run.
    A user configuration file created: {constants.CONFIG_USER}
    At minimum you edit this file and add a display_type and enable one plugin.

    Edit the configuration file with:
       $ nano {constants.CONFIG_USER}'''
                do_exit(0, msg)
        
    config_files_list.append(config_file)
    
    
    logger.info(f'using configuration files to configure PaperPi: {config_files_list}')
    config_files = ArgConfigParse.ConfigFile(config_files_list, ignore_missing=True)
    try:
        config_files.parse_config()
    except DuplicateSectionError as e:
        logger.error(f'{e}')
        config_files = None
    except ConfigParserError as e:
        logging.error(f'error processing config file: {e}')
        config_files = None

    return config_files

# %%
def clean_up(cache=None, screen=None, no_wipe=False):
    '''clean up the screen and cache
    
    Args:
        cache(cache obj): cache object to use for cleanup up
        screen(Screen obj): screen to clear
        no_wipe(bool): True - leave last image on screen; False - wipe screen
    '''
    logging.info('cleaning up')
    try:
        logging.debug('clearing cache')
        cache.cleanup()
    except AttributeError:
        logging.debug('no cache passed, skipping')
    
    if no_wipe:
        logging.info('not clearing screen due to [main][no_wipe]=True')
    else:
        try:
            logging.debug('clearing screen')
            screen.clearEPD()
            screen.module_exit()
        except AttributeError:
            logging.debug('no screen passed, skipping cleanup')
        
    logging.debug('cleanup completed')
    return

# %%
def build_plugins_list(config, resolution, cache):
    '''Build a dictionary of configured plugin objects
    
    Args:
        config(dict): configuration dictionary 
        resolution(tuple): X, Y resolution of screen
        cache(obj: Cache): cache object for managing downloads of images
        
    Returns:
        dict of Plugin'''
    
    def font_path(layout):
        '''add font path to layout'''
        for k, block in layout.items():
            font = block.get('font', None)
            if font:
                font = font.format(constants.FONTS)
                block['font'] = font
        return layout
    
    # get the expected key-word args from the Plugin() spec
    spec_kwargs = getfullargspec(Plugin).args

    plugins = []
    
    for section, values in config.items():
        if section.startswith('Plugin:'):
            logger.info(f'[[ {section} ]]')
            
            plugin_config = {}
            # add all the spec_kwargs from the config
            plugin_kwargs = {}
            for key, val in values.items():
                if key in spec_kwargs:
                    plugin_config[key] = val
                else:
                    # add everything that is not one of the spec_kwargs to this dict
                    plugin_kwargs[key] = val

            # populate the kwargs plugin_config dict that will be passed to the Plugin() object
            plugin_config['name'] = section
            plugin_config['resolution'] = resolution
            plugin_config['config'] = plugin_kwargs
            plugin_config['cache'] = cache
            plugin_config['force_onebit'] = config['main']['force_onebit']
            plugin_config['screen_mode'] = config['main']['screen_mode']
            plugin_config['plugin_timeout'] = config['main'].get('plugin_timeout', 35)
            plugin_config['plugin_debug'] = config['main'].get('plugin_debug', False)
            plugin_config['plugin_debug_root'] = config['main'].get('plugin_debug_root', '/tmp/PaperPi-debug')
            plugin_config['max_debug_files'] = config['main'].get('max_debug_files', 10)
            # force layout to one-bit mode for non-HD screens
#             if not config['main'].get('display_type') == 'HD':
#                 plugin_config['force_onebit'] = True

            logging.debug(f'plugin_config: {plugin_config}')
    
            try:
                module = import_module(f'{constants.PLUGINS}.{values["plugin"]}')
                plugin_config['update_function'] = module.update_function
                layout = getattr(module.layout, values['layout'])
                layout = font_path(layout)
                plugin_config['layout'] = layout
            except KeyError as e:
                logger.info('no module specified; skipping update_function and layout')
                continue
            except ModuleNotFoundError as e:
                logger.warning(f'error: {e} while loading module {constants.PLUGINS}.{values["plugin"]}')
                logger.warning(f'skipping plugin')
                continue
            except AttributeError as e:
                logger.warning(f'could not find layout "{plugin_config["layout"]}" in {plugin_config["name"]}')
                logger.warning(f'skipping plugin')
                continue
            except Exception as e:
                logger.error(f'plugin failed to load due to error: {e}')
                logger.error('skipping plugin')
                continue
                
            my_plugin = Plugin(**plugin_config)
            try:
                my_plugin.update()
            except AttributeError as e:
                logger.warning(f'ignoring plugin {my_plugin.name} due to missing update_function')
                logger.warning(f'plugin threw error: {e}')
                continue
            except Exception as e:
                logger.warning(f'{my_plugin.name} crashed while initializing: {e}')
                logger.warning(f'excluding plugin')
                continue
            logger.info(f'appending plugin {my_plugin.name}')
            
    
            plugins.append(my_plugin)
            
    
    return plugins

# %%
def setup_splash(config, resolution):
    if config['main'].get('splash', False):
        logger.debug('displaying splash screen')
        from plugins.splash_screen import splash_screen
        splash_config = {
            'name': 'Splash Screen',
            'layout': splash_screen.layout.layout,
            'update_function': splash_screen.update_function,
            'resolution': resolution,
        }
        splash = Plugin(**splash_config)
        splash.update(app_name=constants.APP_NAME, 
                      version=constants.VERSION, 
                      url=constants.URL)
    else:
        logger.debug('skipping splash screen')
        splash = False
    
    return splash

# %%
def setup_display(config):
    def ret_obj(obj=None, status=0, message=None):
        return{'obj': obj, 'status': status, 'message': message} 
    
    keyError_fmt = 'configuration KeyError: section[{}], key: {}'    
    
    moduleNotFoundError_fmt = 'could not load epd module {} -- error: {}'
    
    epd = config['main'].get('display_type', None)
    vcom = config['main'].get('vcom', None)
    mirror = config['main'].get('mirror', False)
        
    try:
        screen = Screen(epd=epd, vcom=vcom)
        # this may not be necessary; most writes necessarily involve wiping the screen
#         screen.clearEPD()
    except ScreenError as e:
        logging.critical('Error loading epd from configuration')
        return_val = ret_obj(None, 1, moduleNotFoundError_fmt.format(epd, e))
        return return_val
    except PermissionError as e:
        logging.critical(f'Error initializing EPD: {e}')
        logging.critical(f'The user executing {constants.app_name} does not have access to the SPI device.')
        return_val = ret_obj(None, 1, 'This user does not have access to the SPI group\nThis can typically be resolved by running:\n$ sudo groupadd <username> spi')
        return return_val
    except FileNotFoundError as e:
        logging.critical(f'Error initializing EPD: {e}')
        logging.critical(f'It appears that SPI is not enabled on this Pi. Try:')
        logging.critical(f'   $ sudo raspi-config nonint do_spi 0')
        return_val = ret_obj(None, 1, moduleNotFoundError_fmt.format(epd, e))
        return return_val
    
    
    try:
        screen.rotation = config['main'].get('rotation', 0)
    except (TypeError, ValueError) as e:
        logger.error('invalid screen rotation [main][rotation] - acceptable values are (0, 90, -90, 180)')
        return_val = ret_obj(None, 1, keyError_format.format('main', 'rotation'))
        return return_val
    
    try:
        screen.mirror = config['main'].get('mirror', False)
    except (TypeError, ValueError) as e:
        logger.error('invalid mirror value [main][mirror] - acceptable values are: (True, False)')
        return_val = ret_obj(None, 1, keyError_format.format('main', 'rotation'))
        return return_val
            
    
    return ret_obj(obj=screen)

# %%
def update_loop(plugins, screen, max_refresh=5):
    
    def _update_plugins(force_update=False):
        '''private function for updating plugins'''
        s = ' '*5
        logger.info(f'>>__________UPDATING PLUGINS__________<<')
        logger.debug(f'{len(plugins)} total plugins available')
        my_priority_list = [2**16]
        plugin_crashed = False
        for plugin in plugins:
            logger.info(f'{"#"*10}{plugin.name}{"#"*10}')

            try:
                if force_update:
                    logger.info(f'{s}forcing update')
                    plugin.force_update()
                else:
                    plugin.update()
            except Exception as e:
                logging.error(f'{Plugin} crashed while updating: {e}')
                plugin_crashed = True

                if plugin_crashed:
                    logging.warning('due to crash, resetting plugin priority and update status')
                    plugin.priority = 2**15

            logger.info(f'{s}PRIORITY: {plugin.priority} of max {plugin.max_priority}')
            my_priority_list.append(plugin.priority)

            logger.debug(f'{s}DATA: {len(plugin.data)} elements')
            logger.debug(f'{s}IMAGE: {plugin.image}')

        return my_priority_list
    
    logger.debug(f'max refresh before total wipe: {max_refresh}')
    
    logger.info(f'starting update loop with {len(plugins)} plugins')
    logger.debug(f'plugins: {plugins}')
    
    exit_code = 1
    priority_list = []
    priority_list = _update_plugins(force_update=True)
    # cycle to next item in list
    plugin_cycle = cycle(plugins)
    current_plugin = next(plugin_cycle)
    refresh_count = 0
    current_hash = ''
    # lower numbers are of greater importance
    max_priority = min(priority_list)
    last_priority = max_priority
    
    # display the first plugin with appropriately priority
    for i in range(0, len(plugins)):
        if current_plugin.priority <= max_priority:
            current_timer = Update()
            current_plugin_active = True
            logger.info(f'DISPLAY PLUGIUN: {current_plugin.name}')
            break
        else:
            current_plugin = next(plugin_cycle)

    
    interrupt_handler = InterruptHandler()
    # update loop
    while not interrupt_handler.kill_now:
        logger.debug('^>^>^>^>^>^> UPDATE LOOP START <^<^<^<^<^<^')
        logger.info(f'{current_plugin.name}--display for: {current_plugin.min_display_time-current_timer.last_updated:.1f} of {current_plugin.min_display_time} seconds')
        
        priority_list = _update_plugins()
        logging.debug(f'priority_list: {priority_list}')
        last_priority = max_priority
        max_priority = min(priority_list)
        logging.debug(f'previous max: {last_priority}; current max: {max_priority}')
        
        

        
        # if the timer has expired or the priority has increased, display a different plugin
        if current_timer.last_updated > current_plugin.min_display_time:
            logger.info(f'display time for {current_plugin} elapsed, cycling to next')
            current_plugin_active = False
        
        # was max_priority > last_priority - changed to "<"
        if max_priority < last_priority:
            logger.info(f'priority level increased; cycling to higher priority plugin')
            current_plugin_active = False
            
        
        if not current_plugin_active:
            logger.debug(f'{current_plugin} inactive; searching for next active plugin')
            for attempt in range(0, len(plugins)):
                current_plugin = next(plugin_cycle)
                logger.debug(f'checking plugin: {current_plugin}')
                if current_plugin.priority <= max_priority:
                    current_plugin_active = True
                    logger.debug(f'using plugin: {current_plugin}' )
                    current_timer.update()
                    break

        # check data-hash for plugin; only update screen if hash has changed to avoid uneccessary updates
        logging.debug(f'comparing plugin hashes current: {current_hash} - active plugin hash: {current_plugin.hash}')
        if current_hash != current_plugin.hash:
            logger.debug('screen update required')
            current_hash = current_plugin.hash
            
            if refresh_count >= max_refresh-1 and screen.HD:
                logger.debug(f'{refresh_count} reached maximum of {max_refresh}')
                refresh_count = 0
                screen.clearEPD()
                
            try:
                screen.writeEPD(current_plugin.image)
            except FileNotFoundError as e:
                msg = 'SPI does not appear to be enabled. Paperpi requires SPI access'
                logging.critical(msg)
                do_exit(1, msg)
            except ScreenError as e:
                logging.critical(f'{current_plugin.name} returned invalid image data; screen update skipped')
                logging.debug(f'DATA: {current_plugin.data}')
                logging.debug(f'IMAGE: {current_plugin.image}')
                logging.debug(f'IMAGE STRING: {str(current_plugin.image)}')
                current_plugin_active = False
        else:
            logging.debug('plugin data not refreshed, skipping screen update')

            
        logger.debug('^>^>^>^>^>^> UPDATE LOOP END <^<^<^<^<^<^')
        sleep(constants.UPDATE_SLEEP)

# %%
def main():
    cmd_args = get_cmd_line_args()
    
    
    if hasattr(cmd_args, 'unknown'):
        print(f'Unknown arguments: {cmd_args.unknown}\n\n')
        cmd_args.parser.print_help()
        return
    
    config_files = get_config_files(cmd_args)
    
    if not config_files:
        print('Fatal error collecting configuration files. See the logs.')
        return
    
    # merge the config files and the command line arguments (right-most overwrites left)
    config = ArgConfigParse.merge_dict(config_files.config_dict, cmd_args.nested_opts_dict)
    
    # convert all config values to int, float, etc.
    config = config_str_to_val(config)

    log_level = config['main'].get('log_level', 'INFO')
        
    logger.setLevel(log_level)
    logging.root.setLevel(log_level)    

    
    if cmd_args.options.version:
        print(constants.VERSION_STRING)
        return

    if cmd_args.options.compatible:
        print('Compatible WaveShare Displays:\n')
        Screen.list_compatible()
        return
    
    # if cmd_args.options.list_plugins:
    #     get_help.get_help(plugin_path=Path(constants.BASE_DIRECTORY)/'plugins')
    #     return
    
    # if cmd_args.options.plugin_info:
    #     get_help.get_help(cmd_args.options.plugin_info)
    #     return
    
    # if cmd_args.options.run_plugin_func:
    #     run_module.run_module(cmd_args.options.run_plugin_func)
    #     return    

    if cmd_args.options.add_config:
        try:
            my_plugin = cmd_args.options.add_config[0]
            config_opt = cmd_args.options.add_config[1]
        except IndexError:
            my_plugin = None
            config_opt = None
            
        if config_opt == 'user':
            config_opt = constants.CONFIG_USER
        elif config_opt == 'daemon':
            config_opt = constants.CONFIG_SYSTEM
        else:
            config_opt = None
        
        run_module.add_config(module=my_plugin, config_file=config_opt)
        return    
    
    log_level = config['main'].get('log_level', 'INFO')

    if cmd_args.options.list_plugins:
        get_help.get_help(plugin_path=Path(constants.BASE_DIRECTORY)/'plugins')
        return
    
    if cmd_args.options.plugin_info:
        get_help.get_help(cmd_args.options.plugin_info)
        return
    
    if cmd_args.options.run_plugin_func:
        run_module.run_module(cmd_args.options.run_plugin_func)
        return    

    if config.get('main', {}).get('plugin_debug', False):
        logging.root.setLevel('DEBUG')
        logger.debug('enhanced plugin debugging is active')
        logger.debug(f"plugin debug files can be found in: {config.get('main', {}).get('plugin_debug_root', 'PATH NOT FOUND')}")
        
    
    
    logger.info(f'********** {constants.APP_NAME} {constants.VERSION} Starting **********')
    if cmd_args.options.main__daemon:
        logger.info(f'{constants.APP_NAME} is running in daemon mode')
    else:
        logger.info(f'{constants.APP_NAME} is running in on-demand mode')


        
    logger.debug(f'configuration:\n{config}\n\n')

    
    screen_return = setup_display(config)

    if screen_return['obj']:
        screen = screen_return['obj']
    else:
        clean_up(None, None)
        logger.error(f'config files used: {config_files.config_files}')
        do_exit(**screen_return)
    
    # force to one-bit mode for non HD and non-color screens
    # screens that have mode 1 are always one bit
    if screen.mode == '1': 
        one_bit = True
    # if color is true or the display is HD: one_bit == False
    elif config['main'].get('color', False) or config['main'].get('display_type', 'none').lower() == 'hd':
        one_bit = False
    else:
        # fall back to one bit
        one_bit = True
            
    config['main']['force_onebit'] = one_bit
    config['main']['screen_mode'] = screen.mode
    
    logging.info('configured')
            
    splash = setup_splash(config, screen.resolution)
    
    if splash:
        splash_kwargs = {
            'app_name': constants.APP_NAME,
            'version': constants.VERSION,
            'url': constants.URL            
        }
        splash.force_update(**splash_kwargs)
        logger.debug('display splash screen')
        try:
            screen.writeEPD(splash.image)
        except FileNotFoundError as e:
            msg = 'SPI does not appear to be enabled. Paperpi requires SPI access'
            logging.critical(msg)
            do_exit(1, msg)            
        except ScreenError as e:
            logging.critical(f'Could not write to EPD: {e}')
            
    cache = CacheFiles(path_prefix=constants.APP_NAME)
    

    
    plugins = build_plugins_list(config=config, resolution=screen.resolution, 
                                cache=cache)

    
    exit_code = update_loop(plugins=plugins, screen=screen, max_refresh=config['main'].get('max_refresh', 5))
    
    clean_up(cache=cache, screen=screen, no_wipe=config['main'].get('no_wipe', False))
    
    return  exit_code

# %%
# add test arguments here 
# test_args = ["--run_plugin_func", "lms_client.scan_servers"]
test_args = []

# %%
if __name__ == "__main__":
    # remove jupyter runtime junk for testing

    if '-f' in sys.argv:
        i = sys.argv.index('-f')
        if 'jupyter/' in sys.argv[i+1]:
            try:
                t = sys.argv[:i] + sys.argv[i+2:]
                sys.argv = t
            except ValueError:
                    pass
    for i in test_args:
        if i not in sys.argv:
            sys.argv.append(i)
    
    exit_code = main()
    print(exit_code)
    sys.exit(exit_code)
# Out:
# 18:53:40 2117374890:get_config_files:48  :INFO       - using configuration files to configure PaperPi: [PosixPath('/home/pi/src/PaperPi/paperpi/config/paperpi.ini'), PosixPath('/home/pi/.config/com.txoof.paperpi/paperpi.ini')]
# 18:53:40 1495611535:main      :88  :INFO       - ********** PaperPi 0.5.8.0 10Sept24 Starting **********
# 18:53:40 1495611535:main      :92  :INFO       - PaperPi is running in on-demand mode
# 18:53:40 Screen  :_load_hd  :429 :DEBUG      - configuring IT8951 epd
# 18:53:43 Screen  :epd       :351 :DEBUG      - epd configuration {'epd': <IT8951.display.AutoEPDDisplay object at 0x7fb60a0d10>, 'resolution': [1200, 825], 'clear_args': {}, 'one_bit_display': False, 'constants': <module 'IT8951.constants' from '/home/pi/src/PaperPi/venv_paperpi-9876705927/lib/python3.11/site-packages/IT8951/constants.py'>, 'mode': 'L'}
# 18:53:43 Screen  :rotation  :397 :DEBUG      - rotation=0, resolution=[1200, 825]
# 18:53:43 Screen  :mirror    :409 :DEBUG      - mirror output: False
# 18:53:43 Screen  :rotation  :397 :DEBUG      - rotation=0, resolution=[1200, 825]
# 18:53:43 Screen  :mirror    :409 :DEBUG      - mirror output: False
# 18:53:43 1495611535:main      :122 :INFO       - configured
# 18:53:43 Layout  :_add_defaults:195 :DEBUG      - [[----checking default values for layout----]
# 18:53:43 Layout  :_add_defaults:197 :DEBUG      - section: [-----------app_name-----------]
# 18:53:43 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:43 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:43 Layout  :_add_defaults:197 :DEBUG      - section: [-----------version------------]
# 18:53:43 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:43 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:43 Layout  :_add_defaults:197 :DEBUG      - section: [-------------url--------------]
# 18:53:43 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:43 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:43 Layout  :_calculate_layout:238 :DEBUG      - [[....calculating layouts....]]
# 18:53:43 Layout  :_calculate_layout:240 :INFO       - section: [...........app_name...........]
# 18:53:43 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:43 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.6
# 18:53:43 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 495), padded_area: (1180, 475)
# 18:53:43 Layout  :_calculate_layout:279 :DEBUG      - absolute coordinates provided
# 18:53:43 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 0)
# 18:53:43 Layout  :_calculate_layout:240 :INFO       - section: [...........version............]
# 18:53:43 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:43 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.1
# 18:53:43 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 82), padded_area: (1180, 62)
# 18:53:43 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:43 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 495)
# 18:53:43 Layout  :_calculate_layout:240 :INFO       - section: [.............url..............]
# 18:53:43 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:43 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.3
# 18:53:43 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 248), padded_area: (1180, 228)
# 18:53:43 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:43 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 577)
# 18:53:43 Layout  :layout    :136 :DEBUG      - layout config: resolution, [1200, 825], force_onebit: False, mode: 1
# 18:53:43 Layout  :layout    :137 :INFO       - [[____SETTING SECTION BLOCKS____]]
# 18:53:43 Layout  :set_block :155 :INFO       - setting section: [___________app_name___________]
# 18:53:43 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:44 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:44 Layout  :_scale_font:317 :DEBUG      - calculated font size: 369
# 18:53:44 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:44 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:44 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:44 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:44 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:44 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:44 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:44 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:44 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:44 Block   :area      :311 :DEBUG      - block area: (1200, 495)
# 18:53:44 Block   :padding   :338 :DEBUG      - padded area: [1180, 475]
# 18:53:44 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:44 Block   :font_size :807 :DEBUG      - resetting font to match size 369
# 18:53:44 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Anton', 'Regular') at size 369
# 18:53:44 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 168.80583501006035
# 18:53:44 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 7
# 18:53:44 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:44 Block   :_text2image:993 :DEBUG      - text size: (699, 442)
# 18:53:44 Block   :_text2image:1032:DEBUG      - pasting hcenterd
# 18:53:44 Block   :_text2image:1036:DEBUG      - pasting vcentered
# 18:53:44 Block   :_text2image:1043:DEBUG      - paste coordinates: (250, 26)
# 18:53:44 Layout  :set_block :155 :INFO       - setting section: [___________version____________]
# 18:53:44 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:44 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:44 Layout  :_scale_font:317 :DEBUG      - calculated font size: 48
# 18:53:44 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:44 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:44 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:44 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:44 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:44 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:44 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:44 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:44 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:44 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:44 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:44 Block   :area      :311 :DEBUG      - block area: (1200, 82)
# 18:53:44 Block   :padding   :338 :DEBUG      - padded area: [1180, 62]
# 18:53:44 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:44 Block   :font_size :807 :DEBUG      - resetting font to match size 48
# 18:53:44 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Dosis', 'SemiBold') at size 48
# 18:53:45 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 23.40165995975855
# 18:53:45 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 50
# 18:53:45 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:45 Block   :_text2image:993 :DEBUG      - text size: (109, 47)
# 18:53:45 Block   :_text2image:1032:DEBUG      - pasting hcenterd
# 18:53:45 Block   :_text2image:1036:DEBUG      - pasting vcentered
# 18:53:45 Block   :_text2image:1043:DEBUG      - paste coordinates: (545, 17)
# 18:53:45 Layout  :set_block :155 :INFO       - setting section: [_____________url______________]
# 18:53:45 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:45 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:45 Layout  :_scale_font:317 :DEBUG      - calculated font size: 90
# 18:53:45 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:45 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:45 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:45 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:45 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:45 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:45 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:45 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:45 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:45 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:45 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:45 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:45 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:45 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:45 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:45 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:45 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:45 Block   :area      :311 :DEBUG      - block area: (1200, 248)
# 18:53:45 Block   :padding   :338 :DEBUG      - padded area: [1180, 228]
# 18:53:45 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:45 Block   :font_size :807 :DEBUG      - resetting font to match size 90
# 18:53:45 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Dosis', 'SemiBold') at size 90
# 18:53:46 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 43.88028169014085
# 18:53:46 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 27
# 18:53:46 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:46 Block   :_text2image:993 :DEBUG      - text size: (205, 88)
# 18:53:46 Block   :_text2image:1032:DEBUG      - pasting hcenterd
# 18:53:46 Block   :_text2image:1036:DEBUG      - pasting vcentered
# 18:53:46 Block   :_text2image:1043:DEBUG      - paste coordinates: (497, 80)
# 18:53:46 Plugin  :update    :195 :INFO       - starting update - timeout: 20 sec
# 18:53:46 Block   :_text_formatter:949 :DEBUG      - formatting string: PaperPi
# 18:53:46 Block   :_text2image:993 :DEBUG      - text size: (1108, 456)
# 18:53:46 Block   :_text2image:1032:DEBUG      - pasting hcenterd
# 18:53:46 Block   :_text2image:1036:DEBUG      - pasting vcentered
# 18:53:46 Block   :_text2image:1043:DEBUG      - paste coordinates: (46, 19)
# 18:53:46 Block   :_text_formatter:949 :DEBUG      - formatting string: 0.5.8.0 10Sept24
# 18:53:46 Block   :_text2image:993 :DEBUG      - text size: (309, 47)
# 18:53:46 Block   :_text2image:1032:DEBUG      - pasting hcenterd
# 18:53:46 Block   :_text2image:1036:DEBUG      - pasting vcentered
# 18:53:46 Block   :_text2image:1043:DEBUG      - paste coordinates: (445, 17)
# 18:53:46 Block   :_text_formatter:949 :DEBUG      - formatting string: https://github.com/ txoof/PaperPi
# 18:53:46 Block   :_text2image:993 :DEBUG      - text size: (708, 188)
# 18:53:46 Block   :_text2image:1032:DEBUG      - pasting hcenterd
# 18:53:46 Block   :_text2image:1036:DEBUG      - pasting vcentered
# 18:53:46 Block   :_text2image:1043:DEBUG      - paste coordinates: (246, 30)
# 18:53:46 Plugin  :force_update:228 :INFO       - forced update of plugin: Splash Screen
# 18:53:46 Plugin  :update    :195 :INFO       - starting update - timeout: 20 sec
# 18:53:46 Plugin  :update    :209 :DEBUG      - data has not changed since last update; plugin will not update
# 18:53:46 Screen  :wrapper   :260 :DEBUG      - initing display
# 18:53:46 Screen  :wrapper   :284 :DEBUG      - HD display
# 18:53:46 Screen  :_full_writeEPD_hd:634 :DEBUG      - writing to display using GC16 (full display update)
# 18:53:46 Screen  :wrapper   :291 :DEBUG      - sleeping display
# 18:53:47 1184866979:build_plugins_list:28  :INFO       - [[ Plugin: default fallback plugin ]]
# 18:53:47 1184866979:build_plugins_list:55  :DEBUG      - plugin_config: {'layout': 'layout', 'refresh_rate': 30, 'min_display_time': 60, 'max_priority': 32768, 'name': 'Plugin: default fallback plugin', 'resolution': [1200, 825], 'config': {'plugin': 'default'}, 'cache': CacheFiles(/tmp/PaperPi_45fcmr_k), 'force_onebit': False, 'screen_mode': 'L', 'plugin_timeout': 30, 'plugin_debug': True, 'plugin_debug_root': '/tmp/PaperPi-Debugging/', 'max_debug_files': 10}
# 18:53:47 Layout  :_add_defaults:195 :DEBUG      - [[----checking default values for layout----]
# 18:53:47 Layout  :_add_defaults:197 :DEBUG      - section: [----------digit_time----------]
# 18:53:47 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:47 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:47 Layout  :_add_defaults:222 :DEBUG      - adding "relative: False"
# 18:53:47 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:47 Layout  :_add_defaults:222 :DEBUG      - adding "padding: 0"
# 18:53:47 Layout  :_add_defaults:197 :DEBUG      - section: [-------------msg--------------]
# 18:53:47 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:47 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:47 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:47 Layout  :_add_defaults:222 :DEBUG      - adding "padding: 0"
# 18:53:47 Layout  :_calculate_layout:238 :DEBUG      - [[....calculating layouts....]]
# 18:53:47 Layout  :_calculate_layout:240 :INFO       - section: [..........digit_time..........]
# 18:53:47 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:47 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.5
# 18:53:47 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 412), padded_area: (1200, 412)
# 18:53:47 Layout  :_calculate_layout:279 :DEBUG      - absolute coordinates provided
# 18:53:47 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 0)
# 18:53:47 Layout  :_calculate_layout:240 :INFO       - section: [.............msg..............]
# 18:53:47 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:47 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.5
# 18:53:47 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 412), padded_area: (1200, 412)
# 18:53:47 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:47 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 412)
# 18:53:47 Layout  :layout    :136 :DEBUG      - layout config: resolution, [1200, 825], force_onebit: False, mode: L
# 18:53:47 Layout  :layout    :137 :INFO       - [[____SETTING SECTION BLOCKS____]]
# 18:53:47 Layout  :set_block :155 :INFO       - setting section: [__________digit_time__________]
# 18:53:47 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:47 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:47 Layout  :_scale_font:317 :DEBUG      - calculated font size: 102
# 18:53:47 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:47 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:47 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:47 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:47 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:47 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:47 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:47 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:47 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:47 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:47 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:47 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:47 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:47 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:47 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:47 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:47 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:47 Block   :area      :311 :DEBUG      - block area: (1200, 412)
# 18:53:47 Block   :padding   :338 :DEBUG      - padded area: [1200, 412]
# 18:53:47 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:47 Block   :font_size :807 :DEBUG      - resetting font to match size 102
# 18:53:47 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Kanit', 'Medium') at size 102
# 18:53:48 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 56.27313883299799
# 18:53:48 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 21
# 18:53:48 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:48 Block   :_text2image:993 :DEBUG      - text size: (265, 107)
# 18:53:48 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:48 Block   :_text2image:1043:DEBUG      - paste coordinates: (106, 29)
# 18:53:48 Layout  :set_block :155 :INFO       - setting section: [_____________msg______________]
# 18:53:48 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:48 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:48 Layout  :_scale_font:317 :DEBUG      - calculated font size: 76
# 18:53:48 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:48 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:48 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:48 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:48 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:48 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:48 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:48 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:48 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:48 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:48 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:48 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:48 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:48 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:48 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:48 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:48 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:48 Block   :area      :311 :DEBUG      - block area: (1200, 412)
# 18:53:48 Block   :padding   :338 :DEBUG      - padded area: [1200, 412]
# 18:53:48 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:48 Block   :font_size :807 :DEBUG      - resetting font to match size 76
# 18:53:48 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Kanit', 'Medium') at size 76
# 18:53:49 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 41.92806841046278
# 18:53:49 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 29
# 18:53:49 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:49 Block   :_text2image:993 :DEBUG      - text size: (197, 81)
# 18:53:49 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:49 Block   :_text2image:1043:DEBUG      - paste coordinates: (658, 298)
# 18:53:49 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:53:49 Block   :_text_formatter:949 :DEBUG      - formatting string: 18:53:49
# 18:53:49 Block   :_text2image:993 :DEBUG      - text size: (354, 108)
# 18:53:49 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:49 Block   :_text2image:1043:DEBUG      - paste coordinates: (552, 122)
# 18:53:49 Block   :_text_formatter:949 :DEBUG      - formatting string: No plugins are active, check the logs!
# 18:53:49 Block   :_text2image:993 :DEBUG      - text size: (951, 171)
# 18:53:49 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:49 Block   :_text2image:1043:DEBUG      - paste coordinates: (98, 135)
# 18:53:49 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:53:49 1184866979:build_plugins_list:90  :INFO       - appending plugin Plugin: default fallback plugin
# 18:53:49 1184866979:build_plugins_list:28  :INFO       - [[ Plugin: Word Clock ]]
# 18:53:49 1184866979:build_plugins_list:55  :DEBUG      - plugin_config: {'layout': 'layout', 'refresh_rate': 125, 'min_display_time': 40, 'max_priority': 2, 'name': 'Plugin: Word Clock', 'resolution': [1200, 825], 'config': {'plugin': 'word_clock'}, 'cache': CacheFiles(/tmp/PaperPi_45fcmr_k), 'force_onebit': False, 'screen_mode': 'L', 'plugin_timeout': 30, 'plugin_debug': True, 'plugin_debug_root': '/tmp/PaperPi-Debugging/', 'max_debug_files': 10}
# 18:53:49 Layout  :_add_defaults:195 :DEBUG      - [[----checking default values for layout----]
# 18:53:49 Layout  :_add_defaults:197 :DEBUG      - section: [-----------wordtime-----------]
# 18:53:49 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:49 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:49 Layout  :_add_defaults:197 :DEBUG      - section: [-------------time-------------]
# 18:53:49 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:49 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:49 Layout  :_calculate_layout:238 :DEBUG      - [[....calculating layouts....]]
# 18:53:49 Layout  :_calculate_layout:240 :INFO       - section: [...........wordtime...........]
# 18:53:49 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:49 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.9
# 18:53:49 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 742), padded_area: (1190, 732)
# 18:53:49 Layout  :_calculate_layout:279 :DEBUG      - absolute coordinates provided
# 18:53:49 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 0)
# 18:53:49 Layout  :_calculate_layout:240 :INFO       - section: [.............time.............]
# 18:53:49 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:49 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.1
# 18:53:49 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 82), padded_area: (1180, 62)
# 18:53:49 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:49 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 742)
# 18:53:49 Layout  :layout    :136 :DEBUG      - layout config: resolution, [1200, 825], force_onebit: False, mode: L
# 18:53:49 Layout  :layout    :137 :INFO       - [[____SETTING SECTION BLOCKS____]]
# 18:53:49 Layout  :set_block :155 :INFO       - setting section: [___________wordtime___________]
# 18:53:49 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:50 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:50 Layout  :_scale_font:317 :DEBUG      - calculated font size: 190
# 18:53:50 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:50 Block   :bkground  :249 :DEBUG      - set bkground: BLACK
# 18:53:50 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:50 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:50 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:50 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:50 Block   :fill      :286 :DEBUG      - set fill: WHITE
# 18:53:50 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:50 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:50 Block   :area      :311 :DEBUG      - block area: (1200, 742)
# 18:53:50 Block   :padding   :338 :DEBUG      - padded area: [1190, 732]
# 18:53:50 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:50 Block   :font_size :807 :DEBUG      - resetting font to match size 190
# 18:53:50 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Anton', 'Regular') at size 190
# 18:53:50 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 86.9195171026157
# 18:53:50 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 14
# 18:53:50 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:50 Block   :_text2image:993 :DEBUG      - text size: (360, 228)
# 18:53:50 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:50 Block   :_text2image:1043:DEBUG      - paste coordinates: (285, 257)
# 18:53:50 Layout  :set_block :155 :INFO       - setting section: [_____________time_____________]
# 18:53:50 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:50 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:50 Layout  :_scale_font:317 :DEBUG      - calculated font size: 48
# 18:53:50 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:50 Block   :bkground  :249 :DEBUG      - set bkground: BLACK
# 18:53:50 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:50 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:50 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:50 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:50 Block   :fill      :286 :DEBUG      - set fill: WHITE
# 18:53:50 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:50 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:50 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:50 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:50 Block   :area      :311 :DEBUG      - block area: (1200, 82)
# 18:53:50 Block   :padding   :338 :DEBUG      - padded area: [1180, 62]
# 18:53:50 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:50 Block   :font_size :807 :DEBUG      - resetting font to match size 48
# 18:53:50 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Anton', 'Regular') at size 48
# 18:53:51 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 21.958249496981892
# 18:53:51 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 54
# 18:53:51 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:51 Block   :_text2image:993 :DEBUG      - text size: (91, 58)
# 18:53:51 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:51 Block   :_text2image:1043:DEBUG      - paste coordinates: (1004, 11)
# 18:53:51 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:53:51 word_clock:update_function:96  :INFO       - update_function for Plugin: Word Clock
# 18:53:51 word_clock:update_function:107 :DEBUG      - using 18:53
# 18:53:51 Block   :_text_formatter:949 :DEBUG      - formatting string: It's nearly Ten 'Til Seven
# 18:53:51 Block   :_text2image:993 :DEBUG      - text size: (1016, 449)
# 18:53:51 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:51 Block   :_text2image:1043:DEBUG      - paste coordinates: (133, 266)
# 18:53:51 Block   :_text_formatter:949 :DEBUG      - formatting string: 18:53
# 18:53:51 Block   :_text2image:993 :DEBUG      - text size: (99, 58)
# 18:53:51 Block   :_text2image:1027:DEBUG      - pasting using random coordinates
# 18:53:51 Block   :_text2image:1043:DEBUG      - paste coordinates: (181, 12)
# 18:53:51 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:53:51 1184866979:build_plugins_list:90  :INFO       - appending plugin Plugin: Word Clock
# 18:53:51 1184866979:build_plugins_list:28  :INFO       - [[ Plugin: Debugging 50 ]]
# 18:53:51 1184866979:build_plugins_list:55  :DEBUG      - plugin_config: {'layout': 'debugging_basic', 'min_display_time': 50, 'max_priority': 1, 'refresh_rate': 5, 'name': 'Plugin: Debugging 50', 'resolution': [1200, 825], 'config': {'plugin': 'debugging', 'title': 'Debugging 50', 'crash_rate': 0.5, 'max_priority_rate': 0.1, 'min_priority': 2}, 'cache': CacheFiles(/tmp/PaperPi_45fcmr_k), 'force_onebit': False, 'screen_mode': 'L', 'plugin_timeout': 30, 'plugin_debug': True, 'plugin_debug_root': '/tmp/PaperPi-Debugging/', 'max_debug_files': 10}
# 18:53:51 Layout  :_add_defaults:195 :DEBUG      - [[----checking default values for layout----]
# 18:53:51 Layout  :_add_defaults:197 :DEBUG      - section: [------------title-------------]
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "relative: False"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "padding: 0"
# 18:53:51 Layout  :_add_defaults:197 :DEBUG      - section: [----------crash_rate----------]
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "padding: 0"
# 18:53:51 Layout  :_add_defaults:197 :DEBUG      - section: [-----------priority-----------]
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "padding: 0"
# 18:53:51 Layout  :_add_defaults:197 :DEBUG      - section: [----------digit_time----------]
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:51 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:51 Layout  :_add_defaults:222 :DEBUG      - adding "padding: 0"
# 18:53:51 Layout  :_calculate_layout:238 :DEBUG      - [[....calculating layouts....]]
# 18:53:51 Layout  :_calculate_layout:240 :INFO       - section: [............title.............]
# 18:53:51 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:51 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.3333333333333333
# 18:53:51 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 275), padded_area: (1200, 275)
# 18:53:51 Layout  :_calculate_layout:279 :DEBUG      - absolute coordinates provided
# 18:53:51 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 0)
# 18:53:51 Layout  :_calculate_layout:240 :INFO       - section: [..........crash_rate..........]
# 18:53:51 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:51 Layout  :_calculate_layout:245 :DEBUG      - width: 0.5, height: 0.3333333333333333
# 18:53:51 Layout  :_calculate_layout:255 :DEBUG      - area: (600, 275), padded_area: (600, 275)
# 18:53:51 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:51 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 275)
# 18:53:51 Layout  :_calculate_layout:240 :INFO       - section: [...........priority...........]
# 18:53:51 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:51 Layout  :_calculate_layout:245 :DEBUG      - width: 0.5, height: 0.3333333333333333
# 18:53:51 Layout  :_calculate_layout:255 :DEBUG      - area: (600, 275), padded_area: (600, 275)
# 18:53:51 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:51 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (600, 275)
# 18:53:51 Layout  :_calculate_layout:240 :INFO       - section: [..........digit_time..........]
# 18:53:51 Layout  :_calculate_layout:244 :DEBUG      - resolution: [1200, 825]
# 18:53:51 Layout  :_calculate_layout:245 :DEBUG      - width: 1, height: 0.3333333333333333
# 18:53:51 Layout  :_calculate_layout:255 :DEBUG      - area: (1200, 275), padded_area: (1200, 275)
# 18:53:51 Layout  :_calculate_layout:260 :DEBUG      - calculating block position from relative positions
# 18:53:51 Layout  :_calculate_layout:281 :DEBUG      - block coordinates: (0, 550)
# 18:53:51 Layout  :layout    :136 :DEBUG      - layout config: resolution, [1200, 825], force_onebit: False, mode: L
# 18:53:51 Layout  :layout    :137 :INFO       - [[____SETTING SECTION BLOCKS____]]
# 18:53:51 Layout  :set_block :155 :INFO       - setting section: [____________title_____________]
# 18:53:51 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:52 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:52 Layout  :_scale_font:317 :DEBUG      - calculated font size: 102
# 18:53:52 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:52 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:52 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:52 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:52 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:52 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:52 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:52 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:52 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:52 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:52 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:52 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:52 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:52 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:52 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:52 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:52 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:52 Block   :area      :311 :DEBUG      - block area: (1200, 275)
# 18:53:52 Block   :padding   :338 :DEBUG      - padded area: [1200, 275]
# 18:53:52 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:52 Block   :font_size :807 :DEBUG      - resetting font to match size 102
# 18:53:52 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Kanit', 'Medium') at size 102
# 18:53:52 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 56.27313883299799
# 18:53:52 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 21
# 18:53:52 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:52 Block   :_text2image:993 :DEBUG      - text size: (265, 107)
# 18:53:52 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:52 Layout  :set_block :155 :INFO       - setting section: [__________crash_rate__________]
# 18:53:52 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:53 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:53 Layout  :_scale_font:317 :DEBUG      - calculated font size: 102
# 18:53:53 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:53 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:53 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:53 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:53 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:53 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:53 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:53 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:53 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:53 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:53 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:53 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:53 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:53 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:53 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:53 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:53 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:53 Block   :area      :311 :DEBUG      - block area: (600, 275)
# 18:53:53 Block   :padding   :338 :DEBUG      - padded area: [600, 275]
# 18:53:53 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:53 Block   :font_size :807 :DEBUG      - resetting font to match size 102
# 18:53:53 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Kanit', 'Medium') at size 102
# 18:53:53 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 56.27313883299799
# 18:53:53 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 11
# 18:53:53 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:53 Block   :_text2image:993 :DEBUG      - text size: (265, 107)
# 18:53:53 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:53 Layout  :set_block :155 :INFO       - setting section: [___________priority___________]
# 18:53:53 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:54 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:54 Layout  :_scale_font:317 :DEBUG      - calculated font size: 102
# 18:53:54 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:54 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:54 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:54 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:54 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:54 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:54 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:54 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:54 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:54 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:54 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:54 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:54 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:54 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:54 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:54 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:54 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:54 Block   :area      :311 :DEBUG      - block area: (600, 275)
# 18:53:54 Block   :padding   :338 :DEBUG      - padded area: [600, 275]
# 18:53:54 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:54 Block   :font_size :807 :DEBUG      - resetting font to match size 102
# 18:53:54 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Kanit', 'Medium') at size 102
# 18:53:54 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 56.27313883299799
# 18:53:54 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 11
# 18:53:54 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:54 Block   :_text2image:993 :DEBUG      - text size: (265, 107)
# 18:53:54 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:54 Layout  :set_block :155 :INFO       - setting section: [__________digit_time__________]
# 18:53:54 Layout  :_scale_font:293 :DEBUG      - scaling font size
# 18:53:55 Layout  :_scale_font:314 :DEBUG      - y target size reached
# 18:53:55 Layout  :_scale_font:317 :DEBUG      - calculated font size: 102
# 18:53:55 Layout  :set_block :175 :DEBUG      - setting block type: TextBlock
# 18:53:55 Block   :bkground  :249 :DEBUG      - set bkground: WHITE
# 18:53:55 Block   :_get_color:204 :INFO       - using WaveShare color: WHITE
# 18:53:55 Block   :_get_color:211 :DEBUG      - converting "(255, 255, 255)" to mode: L
# 18:53:55 Block   :_get_color:213 :DEBUG      - using 255
# 18:53:55 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:55 Block   :_get_color:211 :DEBUG      - converting "None" to mode: L
# 18:53:55 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:55 Block   :border_config:266 :DEBUG      - border config: {'fill': 0}
# 18:53:55 Block   :_get_color:211 :DEBUG      - converting "0" to mode: L
# 18:53:55 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:55 Block   :border_config:266 :DEBUG      - border config: {'fill': 0, 'width': 0}
# 18:53:55 Block   :fill      :286 :DEBUG      - set fill: BLACK
# 18:53:55 Block   :_get_color:204 :INFO       - using WaveShare color: BLACK
# 18:53:55 Block   :_get_color:211 :DEBUG      - converting "(0, 0, 0)" to mode: L
# 18:53:55 Block   :_get_color:213 :DEBUG      - using 0
# 18:53:55 Block   :_check_colors:219 :DEBUG      - checking fill and background color
# 18:53:55 Block   :area      :311 :DEBUG      - block area: (1200, 275)
# 18:53:55 Block   :padding   :338 :DEBUG      - padded area: [1200, 275]
# 18:53:55 Block   :__init__  :187 :DEBUG      - creating Block
# 18:53:55 Block   :font_size :807 :DEBUG      - resetting font to match size 102
# 18:53:55 Block   :_calc_maxchar:918 :DEBUG      - calculating maximum characters for font ('Kanit', 'Medium') at size 102
# 18:53:55 Block   :_calc_maxchar:930 :DEBUG      - calculated average character width: 56.27313883299799
# 18:53:55 Block   :_calc_maxchar:933 :DEBUG      - maximum characters per line: 21
# 18:53:55 Block   :_text_formatter:949 :DEBUG      - formatting string: NONE
# 18:53:55 Block   :_text2image:993 :DEBUG      - text size: (265, 107)
# 18:53:55 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:55 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:53:55 debugging:update_function:75  :INFO       - first-run sentinal file: /tmp/PaperPi_45fcmr_k/Debugging50
# 18:53:55 debugging:update_function:89  :INFO       - This is the first run of this plugin; creating sential file: /tmp/PaperPi_45fcmr_k/Debugging50
# 18:53:55 debugging:update_function:91  :INFO       - plugin will not crash on first run
# 18:53:55 debugging:update_function:96  :INFO       - rand_priority: 0.05430146804203695, max_priority_rate: 0.1
# 18:53:55 debugging:update_function:102 :INFO       - priority set to: 1
# 18:53:55 debugging:update_function:112 :INFO       - {'title': 'Debugging 50', 'crash_rate': 'Crash Rate: 50%', 'digit_time': '18:53:55', 'priority': 'priority: 1'}
# 18:53:55 debugging:update_function:119 :INFO       - random crash did not occur: will not throw exception
# 18:53:55 Block   :_text_formatter:949 :DEBUG      - formatting string: Debugging 50
# 18:53:55 Block   :_text2image:993 :DEBUG      - text size: (642, 109)
# 18:53:55 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:55 Block   :_text_formatter:949 :DEBUG      - formatting string: Crash Rate: 50%
# 18:53:55 Block   :_text2image:993 :DEBUG      - text size: (509, 226)
# 18:53:55 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:55 Block   :_text_formatter:949 :DEBUG      - formatting string: 18:53:55
# 18:53:55 Block   :_text2image:993 :DEBUG      - text size: (345, 108)
# 18:53:55 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:55 Block   :_text_formatter:949 :DEBUG      - formatting string: priority: 1
# 18:53:55 Block   :_text2image:993 :DEBUG      - text size: (427, 109)
# 18:53:55 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:53:55 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:53:56 1184866979:build_plugins_list:90  :INFO       - appending plugin Plugin: Debugging 50
# 18:53:56 1184866979:build_plugins_list:28  :INFO       - [[ Plugin: Weather Adis Ababa ]]
# 18:53:56 1184866979:build_plugins_list:55  :DEBUG      - plugin_config: {'layout': 'layout', 'refresh_rate': 300, 'min_display_time': 50, 'max_priority': 2, 'name': 'Plugin: Weather Adis Ababa', 'resolution': [1200, 825], 'config': {'plugin': 'met_no', 'location_name': 'Adis Ababa', 'lat': 9.0, 'lon': 38.75, 'email': 'aaron.ciuffo@gmail.com'}, 'cache': CacheFiles(/tmp/PaperPi_45fcmr_k), 'force_onebit': False, 'screen_mode': 'L', 'plugin_timeout': 30, 'plugin_debug': True, 'plugin_debug_root': '/tmp/PaperPi-Debugging/', 'max_debug_files': 10}
# 18:53:56 Layout  :_add_defaults:195 :DEBUG      - [[----checking default values for layout----]
# 18:53:56 Layout  :_add_defaults:197 :DEBUG      - section: [------forecast_location-------]
# 18:53:56 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:56 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:56 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:56 Layout  :_add_defaults:197 :DEBUG      - section: [------time_updated_local------]
# 18:53:56 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:56 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:56 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# 18:53:56 Layout  :_add_defaults:197 :DEBUG      - section: [---000_forecast_time_local----]
# 18:53:56 Layout  :_add_defaults:217 :DEBUG      - adding "font_size: None"
# 18:53:56 Layout  :_add_defaults:217 :DEBUG      - adding "maxchar: None"
# 18:53:56 Layout  :_add_defaults:222 :DEBUG      - adding "dimensions: None"
# ...
# 18:57:05 librespot_client:_failure  :224 :INFO       - update aborted due to: No API appears to be available on configured port None
# 18:57:05 Plugin  :update    :209 :DEBUG      - data has not changed since last update; plugin will not update
# 18:57:05 Plugin  :write_debug:268 :WARNING    - 'NoneType' object has no attribute 'save': failed to write image file
# 18:57:05 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:57:05 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Librespot/240910-18.55.14.meta
# 18:57:05 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Librespot/240910-18.55.14.pkl
# 18:57:05 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 0
# 18:57:05 801333988:update_loop:70  :DEBUG      - priority_list: [65536, 16384, 2, 32768, 2, 32768]
# 18:57:05 801333988:update_loop:73  :DEBUG      - previous max: 2; current max: 2
# 18:57:05 801333988:update_loop:101 :DEBUG      - comparing plugin hashes current: b6f1ee1717 - active plugin hash: b6f1ee1717
# 18:57:05 801333988:update_loop:124 :DEBUG      - plugin data not refreshed, skipping screen update
# 18:57:10 801333988:update_loop:67  :INFO       - Plugin: Weather Adis Ababa--display for: 33.2 of 50 seconds
# 18:57:10 801333988:_update_plugins:6   :INFO       - >>__________UPDATING PLUGINS__________<<
# 18:57:10 801333988:_update_plugins:11  :INFO       - ##########Plugin: default fallback plugin##########
# 18:57:10 801333988:_update_plugins:27  :INFO       -      PRIORITY: 16384 of max 32768
# 18:57:10 801333988:_update_plugins:11  :INFO       - ##########Plugin: Word Clock##########
# 18:57:10 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:10 801333988:_update_plugins:11  :INFO       - ##########Plugin: Debugging 50##########
# 18:57:10 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:57:10 debugging:update_function:75  :INFO       - first-run sentinal file: /tmp/PaperPi_45fcmr_k/Debugging50
# 18:57:10 debugging:update_function:96  :INFO       - rand_priority: 0.5923269028036021, max_priority_rate: 0.1
# 18:57:10 debugging:update_function:102 :INFO       - priority set to: 2
# 18:57:10 debugging:update_function:112 :INFO       - {'title': 'Debugging 50', 'crash_rate': 'Crash Rate: 50%', 'digit_time': '18:57:10', 'priority': 'priority: 2'}
# 18:57:10 debugging:update_function:119 :INFO       - random crash did not occur: will not throw exception
# 18:57:10 Block   :_text_formatter:949 :DEBUG      - formatting string: Debugging 50
# 18:57:10 Block   :_text2image:993 :DEBUG      - text size: (642, 109)
# 18:57:10 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:10 Block   :_text_formatter:949 :DEBUG      - formatting string: Crash Rate: 50%
# 18:57:10 Block   :_text2image:993 :DEBUG      - text size: (509, 226)
# 18:57:10 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:10 Block   :_text_formatter:949 :DEBUG      - formatting string: 18:57:10
# 18:57:10 Block   :_text2image:993 :DEBUG      - text size: (337, 108)
# 18:57:10 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:10 Block   :_text_formatter:949 :DEBUG      - formatting string: priority: 2
# 18:57:10 Block   :_text2image:993 :DEBUG      - text size: (445, 109)
# 18:57:10 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:10 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:57:10 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Debugging_50/240910-18.55.42.meta
# 18:57:10 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Debugging_50/240910-18.55.42.pkl
# 18:57:10 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Debugging_50/240910-18.55.42.png
# 18:57:10 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 1
# 18:57:10 801333988:_update_plugins:11  :INFO       - ##########Plugin: Weather Adis Ababa##########
# 18:57:10 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:10 801333988:_update_plugins:11  :INFO       - ##########Plugin: Librespot##########
# 18:57:10 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 0
# 18:57:10 801333988:update_loop:70  :DEBUG      - priority_list: [65536, 16384, 2, 2, 2, 32768]
# 18:57:10 801333988:update_loop:73  :DEBUG      - previous max: 2; current max: 2
# 18:57:10 801333988:update_loop:101 :DEBUG      - comparing plugin hashes current: b6f1ee1717 - active plugin hash: b6f1ee1717
# 18:57:10 801333988:update_loop:124 :DEBUG      - plugin data not refreshed, skipping screen update
# 18:57:15 801333988:update_loop:67  :INFO       - Plugin: Weather Adis Ababa--display for: 27.9 of 50 seconds
# 18:57:15 801333988:_update_plugins:6   :INFO       - >>__________UPDATING PLUGINS__________<<
# 18:57:16 801333988:_update_plugins:11  :INFO       - ##########Plugin: default fallback plugin##########
# 18:57:16 801333988:_update_plugins:27  :INFO       -      PRIORITY: 16384 of max 32768
# 18:57:16 801333988:_update_plugins:11  :INFO       - ##########Plugin: Word Clock##########
# 18:57:16 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:16 801333988:_update_plugins:11  :INFO       - ##########Plugin: Debugging 50##########
# 18:57:16 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:57:16 debugging:update_function:75  :INFO       - first-run sentinal file: /tmp/PaperPi_45fcmr_k/Debugging50
# 18:57:16 debugging:update_function:96  :INFO       - rand_priority: 0.7159600540595705, max_priority_rate: 0.1
# 18:57:16 debugging:update_function:102 :INFO       - priority set to: 2
# 18:57:16 debugging:update_function:112 :INFO       - {'title': 'Debugging 50', 'crash_rate': 'Crash Rate: 50%', 'digit_time': '18:57:16', 'priority': 'priority: 2'}
# 18:57:16 debugging:update_function:116 :INFO       - random crash occurred: will throw exception
# 18:57:16 801333988:_update_plugins:20  :ERROR      - <class 'library.Plugin.Plugin'> crashed while updating: random crash occured: random value 0.34 <= 0.50
# 18:57:16 801333988:_update_plugins:24  :WARNING    - due to crash, resetting plugin priority and update status
# 18:57:16 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 1
# 18:57:16 801333988:_update_plugins:11  :INFO       - ##########Plugin: Weather Adis Ababa##########
# 18:57:16 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:16 801333988:_update_plugins:11  :INFO       - ##########Plugin: Librespot##########
# 18:57:16 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:57:16 librespot_client:_detect_api:55  :INFO       - searching for local librespot instances
# 18:57:16 librespot_client:_detect_api:62  :DEBUG      - Polling API librespot-java: http://localhost:24879/token/user-read-playback-state
# 18:57:16 librespot_client:_detect_api:62  :DEBUG      - Polling API go-librespot: http://localhost:24879/status
# 18:57:16 librespot_client:_detect_api:75  :INFO       - no local librespot APIs found on port 24879
# 18:57:16 librespot_client:_detect_api:76  :DEBUG      - is there a go-librespot or librespot-java (spocon) instance configured on 24879?
# 18:57:16 librespot_client:_detect_api:77  :DEBUG      - try starting a stream first
# 18:57:16 librespot_client:_failure  :224 :INFO       - update aborted due to: No API appears to be available on configured port None
# 18:57:16 Plugin  :update    :209 :DEBUG      - data has not changed since last update; plugin will not update
# 18:57:16 Plugin  :write_debug:268 :WARNING    - 'NoneType' object has no attribute 'save': failed to write image file
# 18:57:16 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:57:16 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Librespot/240910-18.55.26.meta
# 18:57:16 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Librespot/240910-18.55.26.pkl
# 18:57:16 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 0
# 18:57:16 801333988:update_loop:70  :DEBUG      - priority_list: [65536, 16384, 2, 32768, 2, 32768]
# 18:57:16 801333988:update_loop:73  :DEBUG      - previous max: 2; current max: 2
# 18:57:16 801333988:update_loop:101 :DEBUG      - comparing plugin hashes current: b6f1ee1717 - active plugin hash: b6f1ee1717
# 18:57:16 801333988:update_loop:124 :DEBUG      - plugin data not refreshed, skipping screen update
# 18:57:21 801333988:update_loop:67  :INFO       - Plugin: Weather Adis Ababa--display for: 22.7 of 50 seconds
# 18:57:21 801333988:_update_plugins:6   :INFO       - >>__________UPDATING PLUGINS__________<<
# 18:57:21 801333988:_update_plugins:11  :INFO       - ##########Plugin: default fallback plugin##########
# 18:57:21 801333988:_update_plugins:27  :INFO       -      PRIORITY: 16384 of max 32768
# 18:57:21 801333988:_update_plugins:11  :INFO       - ##########Plugin: Word Clock##########
# 18:57:21 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:21 801333988:_update_plugins:11  :INFO       - ##########Plugin: Debugging 50##########
# 18:57:21 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:57:21 debugging:update_function:75  :INFO       - first-run sentinal file: /tmp/PaperPi_45fcmr_k/Debugging50
# 18:57:21 debugging:update_function:96  :INFO       - rand_priority: 0.4060190222882648, max_priority_rate: 0.1
# 18:57:21 debugging:update_function:102 :INFO       - priority set to: 2
# 18:57:21 debugging:update_function:112 :INFO       - {'title': 'Debugging 50', 'crash_rate': 'Crash Rate: 50%', 'digit_time': '18:57:21', 'priority': 'priority: 2'}
# 18:57:21 debugging:update_function:116 :INFO       - random crash occurred: will throw exception
# 18:57:21 801333988:_update_plugins:20  :ERROR      - <class 'library.Plugin.Plugin'> crashed while updating: random crash occured: random value 0.25 <= 0.50
# 18:57:21 801333988:_update_plugins:24  :WARNING    - due to crash, resetting plugin priority and update status
# 18:57:21 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 1
# 18:57:21 801333988:_update_plugins:11  :INFO       - ##########Plugin: Weather Adis Ababa##########
# 18:57:21 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:21 801333988:_update_plugins:11  :INFO       - ##########Plugin: Librespot##########
# 18:57:21 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 0
# 18:57:21 801333988:update_loop:70  :DEBUG      - priority_list: [65536, 16384, 2, 32768, 2, 32768]
# 18:57:21 801333988:update_loop:73  :DEBUG      - previous max: 2; current max: 2
# 18:57:21 801333988:update_loop:101 :DEBUG      - comparing plugin hashes current: b6f1ee1717 - active plugin hash: b6f1ee1717
# 18:57:21 801333988:update_loop:124 :DEBUG      - plugin data not refreshed, skipping screen update
# 18:57:26 801333988:update_loop:67  :INFO       - Plugin: Weather Adis Ababa--display for: 17.6 of 50 seconds
# 18:57:26 801333988:_update_plugins:6   :INFO       - >>__________UPDATING PLUGINS__________<<
# 18:57:26 801333988:_update_plugins:11  :INFO       - ##########Plugin: default fallback plugin##########
# 18:57:26 801333988:_update_plugins:27  :INFO       -      PRIORITY: 16384 of max 32768
# 18:57:26 801333988:_update_plugins:11  :INFO       - ##########Plugin: Word Clock##########
# 18:57:26 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:26 801333988:_update_plugins:11  :INFO       - ##########Plugin: Debugging 50##########
# 18:57:26 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:57:26 debugging:update_function:75  :INFO       - first-run sentinal file: /tmp/PaperPi_45fcmr_k/Debugging50
# 18:57:26 debugging:update_function:96  :INFO       - rand_priority: 0.5322340770100075, max_priority_rate: 0.1
# 18:57:26 debugging:update_function:102 :INFO       - priority set to: 2
# 18:57:26 debugging:update_function:112 :INFO       - {'title': 'Debugging 50', 'crash_rate': 'Crash Rate: 50%', 'digit_time': '18:57:26', 'priority': 'priority: 2'}
# 18:57:26 debugging:update_function:119 :INFO       - random crash did not occur: will not throw exception
# 18:57:26 Block   :_text_formatter:949 :DEBUG      - formatting string: Debugging 50
# 18:57:26 Block   :_text2image:993 :DEBUG      - text size: (642, 109)
# 18:57:26 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:26 Block   :_text_formatter:949 :DEBUG      - formatting string: Crash Rate: 50%
# 18:57:26 Block   :_text2image:993 :DEBUG      - text size: (509, 226)
# 18:57:26 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:26 Block   :_text_formatter:949 :DEBUG      - formatting string: 18:57:26
# 18:57:26 Block   :_text2image:993 :DEBUG      - text size: (348, 108)
# 18:57:26 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:26 Block   :_text_formatter:949 :DEBUG      - formatting string: priority: 2
# 18:57:26 Block   :_text2image:993 :DEBUG      - text size: (445, 109)
# 18:57:26 Block   :_text2image:1043:DEBUG      - paste coordinates: (0, 0)
# 18:57:26 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:57:26 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Debugging_50/240910-18.55.48.meta
# 18:57:26 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Debugging_50/240910-18.55.48.pkl
# 18:57:26 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Debugging_50/240910-18.55.48.png
# 18:57:26 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 1
# 18:57:26 801333988:_update_plugins:11  :INFO       - ##########Plugin: Weather Adis Ababa##########
# 18:57:26 801333988:_update_plugins:27  :INFO       -      PRIORITY: 2 of max 2
# 18:57:26 801333988:_update_plugins:11  :INFO       - ##########Plugin: Librespot##########
# 18:57:26 Plugin  :update    :195 :INFO       - starting update - timeout: 30 sec
# 18:57:26 librespot_client:_detect_api:55  :INFO       - searching for local librespot instances
# 18:57:26 librespot_client:_detect_api:62  :DEBUG      - Polling API librespot-java: http://localhost:24879/token/user-read-playback-state
# 18:57:26 librespot_client:_detect_api:62  :DEBUG      - Polling API go-librespot: http://localhost:24879/status
# 18:57:26 librespot_client:_detect_api:75  :INFO       - no local librespot APIs found on port 24879
# 18:57:26 librespot_client:_detect_api:76  :DEBUG      - is there a go-librespot or librespot-java (spocon) instance configured on 24879?
# 18:57:26 librespot_client:_detect_api:77  :DEBUG      - try starting a stream first
# 18:57:26 librespot_client:_failure  :224 :INFO       - update aborted due to: No API appears to be available on configured port None
# 18:57:26 Plugin  :update    :209 :DEBUG      - data has not changed since last update; plugin will not update
# 18:57:26 Plugin  :write_debug:268 :WARNING    - 'NoneType' object has no attribute 'save': failed to write image file
# 18:57:26 Plugin  :__getstate__:63  :DEBUG      - object is being pickled
# 18:57:26 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Librespot/240910-18.55.37.meta
# 18:57:26 Plugin  :rotate_debug:300 :DEBUG      - deleting debug file: /tmp/PaperPi-Debugging/Plugin:_Librespot/240910-18.55.37.pkl
# 18:57:26 801333988:_update_plugins:27  :INFO       -      PRIORITY: 32768 of max 0
# 18:57:26 801333988:update_loop:70  :DEBUG      - priority_list: [65536, 16384, 2, 2, 2, 32768]
# 18:57:26 801333988:update_loop:73  :DEBUG      - previous max: 2; current max: 2
# 18:57:26 801333988:update_loop:101 :DEBUG      - comparing plugin hashes current: b6f1ee1717 - active plugin hash: b6f1ee1717
# 18:57:26 801333988:update_loop:124 :DEBUG      - plugin data not refreshed, skipping screen update
